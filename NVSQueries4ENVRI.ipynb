# %%
#Get the list of vocabularies included in NVS
from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://vocab.nerc.ac.uk/sparql/sparql") #Choose the sparql endpoint you wish
sparql.setQuery("""

prefix skos:<http://www.w3.org/2004/02/skos/core#>
prefix owl:<http://www.w3.org/2002/07/owl#>
prefix dc:<http://purl.org/dc/terms/>

select distinct (?localnam as ?Collection) (?dt as ?Title) (?desc as ?Description) (?crex as ?Governance)  
where {
# ?x a skos:Collection .
optional{?x dc:creator ?cre } .
# ?x dc:title ?dt ;dc:description ?desc .BIND(REPLACE(str(?x), "http://vocab.nerc.ac.uk/collection/", "") AS ?localname) BIND(REPLACE(str(?localname), "/current/", "") AS ?localnam) BIND(if(EXISTS{?x dc:creator ?cre},?cre,"") as ?crex)}  
order by desc(?Rank) 
offset 0 limit 50

""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

for result in results["results"]["bindings"]:
    print(result["Collection"]["value"],result["Title"]["value"],result["Governance"]["value"],sep="---")
# Out:
# A01---International Coastal Atlas Network Coastal Erosion Global Thesaurus---International Coastal Atlas Network
# A02---Oregon Coastal Atlas Coastal Erosion Thesaurus markup terms---Oregon State Coastal Management Program
# A03---Oregon Coastal Atlas Coastal Erosion Thesaurus discovery terms---Oregon State Coastal Management Program
# A04---MIDA Coastal Erosion Thesaurus---Coastal and Marine resources Centre
# A05---AtlantOS Essential Variables---British Oceanographic Data Centre
# B02---BODC-annotated certified reference materials---British Oceanographic Data Centre
# B03---BODC-annotated reference material classifiers---British Oceanographic Data Centre
# B04---BODC people titles---British Oceanographic Data Centre
# B05---BODC governance roles---British Oceanographic Data Centre
# B06---BODC data and metadata integrity checks---British Oceanographic Data Centre
# B07---Sampling net gear deployment vocabulary---British Oceanographic Data Centre
# B09---Celtic Seas Partnership data owner nations bordering MSFD Celtic Seas Marine Region---British Oceanographic Data Centre
# B11---BODC Standard Operating Procedures and Protocols for environmental observations---British Oceanographic Data Centre
# B12---BODC measurement numeric attribute types---British Oceanographic Data Centre
# B20---Celtic Seas Partnership stakeholder sectors---British Oceanographic Data Centre
# B21---Celtic Seas Partnership scale---British Oceanographic Data Centre
# B22---Celtic Seas Partnership governance mechanisms---British Oceanographic Data Centre
# B39---NMF-SS Research Vessel underway variable NetCDF vocabulary---British Oceanographic Data Centre
# B75---BODC Organisations---British Oceanographic Data Centre
# B76---BODC Platform Models---British Oceanographic Data Centre
# C00---BODC Seafloor Depth Data Sources---British Oceanographic Data Centre
# C10---BODC series feature types---British Oceanographic Data Centre
# C16---SeaDataNet sea areas---SeaDataNet
# C17---ICES Platform Codes---International Council for the Exploration of the Sea
# C18---Intergovernmental Oceanographic Commission countries---International Council for the Exploration of the Sea
# C19---SeaVoX salt and fresh water body gazetteer---SeaDataNet and MarineXML Vocabulary Content Governance Group
# C30---Active vocabulary content governance authorities---British Oceanographic Data Centre
# C31---World Meteorological Organisation voluntary observing ship category---World Meteorological Organisation
# C32---International Standards Organisation countries---International Organization for Standardization
# C33---NERC DataGrid data production tool category---Natural Environment Research Council
# C34---Activity purpose categories---SeaDataNet
# C35---European Nature Information System Level 3 Habitats---European Environment Agency
# C36---Monitoring activity legislative drivers---SeaDataNet
# C37---Ten-degree Marsden Squares---SeaDataNet
# C38---SeaDataNet Ports Gazetteer---SeaDataNet
# C39---World Meteorological Organisation sea states---World Meteorological Organisation
# C40---Bonn Agreement pollution report accuracy---Bonn Agreement
# C41---BODC marine pollution sources---British Oceanographic Data Centre
# C43---BODC oilspill quantity---British Oceanographic Data Centre
# C45---Marine Strategy Framework Directive descriptors 2010/477/EU---European Commission
# C46---Marine Strategy Framework Directive criteria 2010/477/EU---European Commission
# C47---Marine Strategy Framework Directive indicators 2010/477/EU---European Commission
# C48---MEDIN Data Guidelines---MEDIN Standards Group
# C59---BODC organisation roles within activities and projects---British Oceanographic Data Centre
# C60---NERC DataGrid vocabulary term relationships---British Oceanographic Data Centre
# C61---BODC post town names---British Oceanographic Data Centre
# C62---BODC administrative region names---British Oceanographic Data Centre
# C64---United Kingdom Charting Progress 2 sea regions---MEDIN Standards Group
# C67---BODC series parameter collection names---British Oceanographic Data Centre
# C71---BODC organisation categories---British Oceanographic Data Centre

# %%
#Search for "salinity" parameters in P01 vocabulary, using indexing
from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://vocab.nerc.ac.uk/sparql/sparql") #Choose the sparql endpoint you wish
sparql.setQuery("""
prefix skos:<http://www.w3.org/2004/02/skos/core#>
prefix text:<http://jena.apache.org/text#>
prefix rdf:<http://www.w3.org/1999/02/22-rdf-syntax-ns#>
prefix owl:<http://www.w3.org/2002/07/owl#> 
prefix dc:<http://purl.org/dc/terms/>

select distinct (?x as ?URL) (?pl as ?PrefLabel) 

where {?x text:query ('*salinity*' 100000). 
<http://vocab.nerc.ac.uk/collection/P01/current/> skos:member ?x. 
# ?x owl:deprecated "false" . ?x skos:prefLabel ?pl . 
FILTER(langMatches(lang(?pl), "en")) 
# ?x dc:identifier ?dci . 
 
 }  
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

for result in results["results"]["bindings"]:
    print(result["URL"]["value"],result["PrefLabel"]["value"],sep="---")
# Out:
# http://vocab.nerc.ac.uk/collection/P01/current/NEUTDENS/---Density (neutral) of the water body
# http://vocab.nerc.ac.uk/collection/P01/current/TCNTTCHO/---Raw signal (counts) of instrument output by thermosalinograph conductivity cell temperature sensor
# http://vocab.nerc.ac.uk/collection/P01/current/SALINACC/---Accuracy of salinity in the water body
# http://vocab.nerc.ac.uk/collection/P01/current/SVELCT01/---Sound velocity in the water body by CTD and computation from temperature and salinity by unspecified algorithm
# http://vocab.nerc.ac.uk/collection/P01/current/TOKGPR01/---Conversion factor (volume to mass) for the water body by CTD and computation of density (in-situ potential temperature surface pressure) reciprocal from pressure, temperature and salinity
# http://vocab.nerc.ac.uk/collection/P01/current/SCOXGCXX/---Saturation of carbon monoxide {CO CAS 630-08-0} in the water body [dissolved plus reactive particulate phase] by computation from concentration
# http://vocab.nerc.ac.uk/collection/P01/current/TOKGPR02/---Conversion factor (volume to mass) for the water body by CTD (second sensor) and computation of density (in-situ potential temperature surface pressure) reciprocal from pressure, temperature and salinity
# http://vocab.nerc.ac.uk/collection/P01/current/ISMA1501/---Concentration (at saturation at atmospheric pressure) of nitrogen {N2} in the water body by computation from salinity and temperature
# http://vocab.nerc.ac.uk/collection/P01/current/TCNTCCHO/---Raw signal (counts) of instrument output by thermosalinograph conductivity sensor
# http://vocab.nerc.ac.uk/collection/P01/current/SVELSG01/---Sound velocity in the water body by thermosalinograph and computation from temperature and salinity by unspecified algorithm
# http://vocab.nerc.ac.uk/collection/P01/current/SVELMV01/---Sound velocity in the water body by moving vessel profiler (MVP) and computation from temperature and salinity by unspecified algorithm
# http://vocab.nerc.ac.uk/collection/P01/current/SSALAGT1/---Salinity of the water body by titration against silver nitrate (AgNO3)
# http://vocab.nerc.ac.uk/collection/P01/current/SSALSL01/---Salinity of the water body by STD
# http://vocab.nerc.ac.uk/collection/P01/current/ODSDM021/---Salinity of the water body
# http://vocab.nerc.ac.uk/collection/P01/current/PSALCU01/---Practical salinity of the water body by CTD and computation using UNESCO 1983 algorithm and NO calibration against independent measurements
# http://vocab.nerc.ac.uk/collection/P01/current/PSALCC01/---Practical salinity of the water body by CTD and computation using UNESCO 1983 algorithm and calibration against independent measurements
# http://vocab.nerc.ac.uk/collection/P01/current/PSALCC02/---Practical salinity of the water body by CTD (second sensor) and computation using UNESCO 1983 algorithm and calibration against independent measurements
# http://vocab.nerc.ac.uk/collection/P01/current/ASLTZZ01/---Absolute salinity of the water body
# http://vocab.nerc.ac.uk/collection/P01/current/DOXYMMOP/---Concentration recalculated to zero salinity of oxygen {O2 CAS 7782-44-7} per unit volume of the water body [dissolved plus reactive particulate phase]
# http://vocab.nerc.ac.uk/collection/P01/current/PSALEXTX/---Practical salinity of experiment water sample by bench salinometer and computation using UNESCO 1983 algorithm
# http://vocab.nerc.ac.uk/collection/P01/current/SSAMP001/---Sampling salinity
# http://vocab.nerc.ac.uk/collection/P01/current/SIGTPR01/---Sigma-theta of the water body by CTD and computation from salinity and potential temperature using UNESCO algorithm
# http://vocab.nerc.ac.uk/collection/P01/current/POTDENS0/---Density (potential) of the water body by computation from salinity and potential temperature using UNESCO algorithm with 0 decibar reference pressure
# http://vocab.nerc.ac.uk/collection/P01/current/TOKGSG01/---Conversion factor (volume to mass) for the water body by thermosalinograph and computation of density reciprocal from pressure, temperature and salinity
# http://vocab.nerc.ac.uk/collection/P01/current/POTDENS1/---Density (potential) of the water body by computation from salinity and potential temperature using UNESCO algorithm with 1000 decibar reference pressure
# http://vocab.nerc.ac.uk/collection/P01/current/POTDENS2/---Density (potential) of the water body by computation from salinity and potential temperature using UNESCO algorithm with 2000 decibar reference pressure
# http://vocab.nerc.ac.uk/collection/P01/current/POTDENS3/---Density (potential) of the water body by computation from salinity and potential temperature using UNESCO algorithm with 3000 decibar reference pressure
# http://vocab.nerc.ac.uk/collection/P01/current/POTMS601/---Potential temperature of the water body by CTD and computation from pressure, salinity and IPTS-68 temperature using UNESCO algorithm
# http://vocab.nerc.ac.uk/collection/P01/current/SVELCV01/---Sound velocity in the water body by computation from temperature and salinity by unspecified algorithm
# http://vocab.nerc.ac.uk/collection/P01/current/POTDENS4/---Density (potential) of the water body by computation from salinity and potential temperature using UNESCO algorithm with 4000 decibar reference pressure
# http://vocab.nerc.ac.uk/collection/P01/current/SIGTEQST/---Sigma-T of the water body by computation from salinity and temperature using UNESCO algorithm
# http://vocab.nerc.ac.uk/collection/P01/current/SIGTPR02/---Sigma-theta of the water body by CTD (second sensor) and computation from salinity and potential temperature using UNESCO algorithm
# http://vocab.nerc.ac.uk/collection/P01/current/SIGTSG01/---Sigma-theta of the water body by thermosalinograph and computation from salinity and potential temperature using UNESCO algorithm
# http://vocab.nerc.ac.uk/collection/P01/current/PSSDEXTX/---Practical salinity standard deviation of experiment water sample by bench salinometer
# http://vocab.nerc.ac.uk/collection/P01/current/SIGTMV01/---Sigma-theta of the water body by moving vessel profiler (MVP) and computation from salinity and potential temperature using UNESCO algorithm
# http://vocab.nerc.ac.uk/collection/P01/current/SIGTEQ01/---Sigma-theta of the water body by computation from salinity and potential temperature using UNESCO algorithm
# http://vocab.nerc.ac.uk/collection/P01/current/SSALBSTX/---Salinity of the water body by bench salinometer
# http://vocab.nerc.ac.uk/collection/P01/current/PSCLCCL1/---Practical salinity of the water body by in-situ conductivity cell and computation using UNESCO 1983 algorithm and laboratory calibrations applied
# http://vocab.nerc.ac.uk/collection/P01/current/PSALTC01/---Practical salinity of the water body by in-situ conductivity cell and computation using UNESCO 1983 algorithm
# http://vocab.nerc.ac.uk/collection/P01/current/PSALBRBR/---Practical salinity of the water body by RBR MS-310 micro-salinometer and computation using UNESCO 1983 algorithm
# http://vocab.nerc.ac.uk/collection/P01/current/PSALSD01/---Practical salinity standard deviation of the water body by CTD and computation using UNESCO 1983 algorithm and calibration against independent measurements
# http://vocab.nerc.ac.uk/collection/P01/current/PSALTC02/---Practical salinity of the water body by in-situ conductivity cell (second sensor) and computation using UNESCO 1983 algorithm
# http://vocab.nerc.ac.uk/collection/P01/current/PSCLCCI1/---Practical salinity of the water body by in-situ conductivity cell and computation using UNESCO 1983 algorithm and calibration against independent measurements
# http://vocab.nerc.ac.uk/collection/P01/current/PSSDBSTX/---Practical salinity standard deviation of the water body by bench salinometer
# http://vocab.nerc.ac.uk/collection/P01/current/PSALTC03/---Practical salinity of the water body by in-situ conductivity cell (third sensor) and computation using UNESCO 1983 algorithm
# http://vocab.nerc.ac.uk/collection/P01/current/PSSDCU01/---Practical salinity standard deviation of the water body by CTD and computation using UNESCO 1983 algorithm and NO calibration against independent measurements
# http://vocab.nerc.ac.uk/collection/P01/current/PSALBSTX/---Practical salinity of the water body by bench salinometer and computation using UNESCO 1983 algorithm
# http://vocab.nerc.ac.uk/collection/P01/current/PSALST01/---Practical salinity of the water body by CTD and computation using UNESCO 1983 algorithm
# http://vocab.nerc.ac.uk/collection/P01/current/PSALTC04/---Practical salinity of the water body by in-situ conductivity cell (fourth sensor) and computation using UNESCO 1983 algorithm
# http://vocab.nerc.ac.uk/collection/P01/current/PSSDCU02/---Practical salinity standard deviation of the water body by CTD (second sensor) and computation using UNESCO 1983 algorithm and NO calibration against independent measurements
# http://vocab.nerc.ac.uk/collection/P01/current/PSALST02/---Practical salinity of the water body by CTD (second sensor) and computation using UNESCO 1983 algorithm
# http://vocab.nerc.ac.uk/collection/P01/current/PSALCU02/---Practical salinity of the water body by CTD (second sensor) and computation using UNESCO 1983 algorithm and NO calibration against independent measurements
# http://vocab.nerc.ac.uk/collection/P01/current/PSALTC05/---Practical salinity of the water body by in-situ conductivity cell (fifth sensor) and computation using UNESCO 1983 algorithm
# http://vocab.nerc.ac.uk/collection/P01/current/PSALTC06/---Practical salinity of the water body by in-situ conductivity cell (sixth sensor) and computation using UNESCO 1983 algorithm
# http://vocab.nerc.ac.uk/collection/P01/current/SSALST01/---Salinity of the water body by CTD
# http://vocab.nerc.ac.uk/collection/P01/current/PSALPR01/---Practical salinity of the water body by conductivity cell and computation using UNESCO 1983 algorithm
# http://vocab.nerc.ac.uk/collection/P01/current/PSLTZZ01/---Practical salinity of the water body
# http://vocab.nerc.ac.uk/collection/P01/current/PSALSG01/---Practical salinity of the water body by thermosalinograph and computation using UNESCO 1983 algorithm and calibration against independent measurements
# http://vocab.nerc.ac.uk/collection/P01/current/PSALPR02/---Practical salinity of the water body by conductivity cell (second sensor) and computation using UNESCO 1983 algorithm
# http://vocab.nerc.ac.uk/collection/P01/current/PSALMC01/---Practical salinity of the water body by moving vessel profiler (MVP) and computation using UNESCO 1983 algorithm and calibration against independent measurements
# http://vocab.nerc.ac.uk/collection/P01/current/PSALSG02/---Practical salinity of the water body by thermosalinograph (second sensor) and computation using UNESCO 1983 algorithm and calibration against independent measurements
# http://vocab.nerc.ac.uk/collection/P01/current/PSALSZ01/---Practical salinity of the water body by thermosalinograph and computation using UNESCO 1983 algorithm
# http://vocab.nerc.ac.uk/collection/P01/current/PSALZZXX/---Practical salinity of the water body by computation using UNESCO 1983 algorithm
# http://vocab.nerc.ac.uk/collection/P01/current/SSALPR01/---Salinity of the water body by conductivity cell
# http://vocab.nerc.ac.uk/collection/P01/current/PSALMV01/---Practical salinity of the water body by moving vessel profiler (MVP) and computation using UNESCO 1983 algorithm
# http://vocab.nerc.ac.uk/collection/P01/current/SSALSG01/---Salinity of the water body by thermosalinograph
# http://vocab.nerc.ac.uk/collection/P01/current/PSALSU01/---Practical salinity of the water body by thermosalinograph and computation using UNESCO 1983 algorithm and NO calibration against independent measurements

# %%
#Easy query to list the structure (equivalent to DESC in oracle) of a triple store
from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://vocab.nerc.ac.uk/sparql/sparql") #Choose the sparql endpoint you wish
sparql.setQuery("""
select distinct ?a where {[] a ?a.} 
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

for result in results["results"]["bindings"]:
    print(result["a"]["value"])
# Out:
# http://www.w3.org/2004/02/skos/core#Concept
# http://www.w3.org/2004/02/skos/core#ConceptScheme
# http://www.w3.org/2004/02/skos/core#Collection
# http://www.w3.org/1999/02/22-rdf-syntax-ns#Statement

# %%
#Get the list of terms of a certain vocabulary: here is L05
#Change L05 to L06 or P08 or the vocabulary you want to get
from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://vocab.nerc.ac.uk/sparql/sparql")
sparql.setQuery("""
prefix skos:<http://www.w3.org/2004/02/skos/core#> 
prefix rdf:<http://www.w3.org/1999/02/22-rdf-syntax-ns#> 
prefix owl:<http://www.w3.org/2002/07/owl#> 
prefix dc:<http://purl.org/dc/terms/> 
select distinct 
(?dci as ?identifier) (?pl as ?PrefLabel) 

where {<http://vocab.nerc.ac.uk/collection/L06/current/>  skos:member ?dt . 
# ?dt dc:identifier ?dci . optional{?dt skos:definition ?def . 
FILTER(langMatches(lang(?def), "en"))} . ?dt skos:prefLabel ?pl ; 
FILTER(langMatches(lang(?pl), "en")) optional{?dt owl:versionInfo ?ver } . 
# ?dt dc:date ?Date ; owl:deprecated ?deprecated . optional {?dt skos:altLabel ?alt }. 
FILTER( ((str(?deprecated)="false")) )BIND(if(bound(?def),?def,"") as ?defx) } 
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

for result in results["results"]["bindings"]:
    print(result["identifier"]["value"],result["PrefLabel"]["value"],sep="---")
# Out:
# SDN:L06::64---geostationary orbiting satellite
# SDN:L06::31---research vessel
# SDN:L06::48---mooring
# SDN:L06::65---orbiting satellite
# SDN:L06::67---helicopter
# SDN:L06::62---aeroplane
# SDN:L06::71---human
# SDN:L06::46---drifting subsurface profiling float
# SDN:L06::77---land-sea mammals
# SDN:L06::25---autonomous underwater vehicle
# SDN:L06::47---float
# SDN:L06::14---land/onshore structure
# SDN:L06::10---land or seafloor
# SDN:L06::41---moored surface buoy
# SDN:L06::45---fixed subsurface vertical profiler
# SDN:L06::43---subsurface mooring
# SDN:L06::11---fixed benthic node
# SDN:L06::16---offshore structure
# SDN:L06::75---cetacean
# SDN:L06::42---drifting surface float
# SDN:L06::6Z---spacecraft
# SDN:L06::21---propelled manned submersible
# SDN:L06::20---submersible
# SDN:L06::3B---autonomous surface water vehicle
# SDN:L06::17---coastal structure
# SDN:L06::9B---hovercraft
# SDN:L06::23---towed unmanned submersible
# SDN:L06::0---unknown
# SDN:L06::12---sea bed vehicle
# SDN:L06::53---tethered balloon
# SDN:L06::19---mesocosm bag
# SDN:L06::96---amphibious crawler
# SDN:L06::39---naval vessel
# SDN:L06::34---vessel at fixed position
# SDN:L06::95---amphibious vehicle
# SDN:L06::74---seabird and duck
# SDN:L06::33---self-propelled small boat
# SDN:L06::68---satellite
# SDN:L06::73---flightless bird
# SDN:L06::76---fish
# SDN:L06::44---drifting subsurface float
# SDN:L06::91---ice island
# SDN:L06::6A---glider
# SDN:L06::22---propelled unmanned submersible
# SDN:L06::51---free-rising balloon
# SDN:L06::24---drifting manned submersible
# SDN:L06::54---airship
# SDN:L06::13---beach/intertidal zone structure
# SDN:L06::60---non-buoyant aircraft
# SDN:L06::32---vessel of opportunity
# SDN:L06::63---rocket
# SDN:L06::92---ice shelf
# SDN:L06::15---land/onshore vehicle
# SDN:L06::35---vessel of opportunity on fixed route
# SDN:L06::70---organism
# SDN:L06::9A---DUKW
# SDN:L06::37---self-propelled boat
# SDN:L06::3Z---surface vessel
# SDN:L06::72---diver
# SDN:L06::6C---parachute
# SDN:L06::6B---kite
# SDN:L06::90---cryosphere
# SDN:L06::3A---man-powered small boat
# SDN:L06::26---lowered unmanned submersible
# SDN:L06::52---free-floating balloon
# SDN:L06::66---manned spacecraft
# SDN:L06::61---research aeroplane
# SDN:L06::30---ship
# SDN:L06::69---autogyro
# SDN:L06::18---river station
# SDN:L06::50---buoyant aircraft
# SDN:L06::38---man-powered boat
# SDN:L06::36---fishing vessel
# SDN:L06::27---sub-surface gliders
# SDN:L06::3C---surface gliders
# SDN:L06::3D---drillship
# SDN:L06::93---pack ice
# SDN:L06::94---drift ice
# SDN:L06::49---surface ice buoy
# SDN:L06::6D---unmanned aerial vehicle
